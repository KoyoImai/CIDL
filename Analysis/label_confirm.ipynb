# %%
import os
from torchvision import datasets

# %%
train_dir = "/home/kouyou/datasets/ImageNet100/train"

train_dset = datasets.ImageFolder(train_dir)

# %%
print(train_dset)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 130054
#     Root location: /home/kouyou/datasets/ImageNet100/train

# %%
train_dset.class_to_idx
# Out:
# {'n01440764': 0,
#  'n01443537': 1,
#  'n01484850': 2,
#  'n01491361': 3,
#  'n01494475': 4,
#  'n01496331': 5,
#  'n01498041': 6,
#  'n01514668': 7,
#  'n01514859': 8,
#  'n01531178': 9,
#  'n01537544': 10,
#  'n01560419': 11,
#  'n01582220': 12,
#  'n01592084': 13,
#  'n01601694': 14,
#  'n01608432': 15,
#  'n01614925': 16,
#  'n01622779': 17,
#  'n01630670': 18,
#  'n01632458': 19,
#  'n01632777': 20,
#  'n01644900': 21,
#  'n01664065': 22,
#  'n01665541': 23,
#  'n01667114': 24,
#  'n01667778': 25,
#  'n01675722': 26,
#  'n01677366': 27,
#  'n01685808': 28,
#  'n01687978': 29,
#  'n01693334': 30,
#  'n01695060': 31,
#  'n01698640': 32,
#  'n01728572': 33,
#  'n01729322': 34,
#  'n01729977': 35,
#  'n01734418': 36,
#  'n01735189': 37,
#  'n01739381': 38,
#  'n01740131': 39,
#  'n01742172': 40,
#  'n01749939': 41,
#  'n01751748': 42,
#  'n01753488': 43,
#  'n01755581': 44,
#  'n01756291': 45,
#  'n01770081': 46,
#  'n01770393': 47,
#  'n01773157': 48,
#  'n01773549': 49,
# ...
